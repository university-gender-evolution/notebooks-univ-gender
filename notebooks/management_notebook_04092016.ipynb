# %% [markdown]
# # Table of Contents
#  <p><div class="lev1"><a href="#Management-Department - Three Model Comparisons"><span class="toc-item-num">1 - </span>Management Department - Three Models</a></div><div class="lev2"><a href="#Data"><span class="toc-item-num">1.1 - </span>Data</a></div><div class="lev3"><a href="#1.2  Model-Specifications"><span class="toc-item-num">1.2 - </span>Model Specifications</a></div><div class="lev3"><a href="#Findings"><span class="toc-item-num">1.3 - </span>Baseline Results</a></div><div class="lev2"><a href="#Long-run-gender-proportion-using-all-3-models"><span class="toc-item-num">1.2 - </span>Long run gender proportion using all 3 models</a></div><div class="lev3"><a href="#Simulation-results"><span class="toc-item-num">1.2.1 - </span>Simulation results</a></div><div class="lev3"><a href="#Analysis"><span class="toc-item-num">1.2.2 - </span>Analysis</a></div><div class="lev2"><a href="#Department-male/female-counts-by-level"><span class="toc-item-num">1.3 - </span>Department male/female counts by level</a></div><div class="lev3"><a href="#Simulation-results---Comparison-of-all-models"><span class="toc-item-num">1.3.1 - </span>Simulation results - Comparison of all models</a></div><div class="lev3"><a href="#Analysis----Comparison-of-all-models"><span class="toc-item-num">1.3.2 - </span>Analysis -- Comparison of all models</a></div><div class="lev4"><a href="#Replication(Promote-hire)-model"><span class="toc-item-num">1.3.2.1 - </span>Replication(Promote-hire) model</a></div><div class="lev4"><a href="#Promote-hire-fp-model"><span class="toc-item-num">1.3.2.2 - </span>Promote-hire fp model</a></div><div class="lev4"><a href="#Hire-promote-model"><span class="toc-item-num">1.3.2.3 - </span>Hire-promote model</a></div><div class="lev2"><a href="#Critical-Parameter-Sweeps-and-Analysis"><span class="toc-item-num">1.4 - </span>Critical Parameter Sweeps and Analysis</a></div><div class="lev3"><a href="#Parameter-sweep:-Promotion-probabilities-level-1--&gt;-2"><span class="toc-item-num">1.4.1 - </span>Parameter sweep: Promotion probabilities level 1 -&gt; 2</a></div><div class="lev4"><a href="#Analysis-of-parameter-sweep:-promotion-probabilities-level-1--&gt;2"><span class="toc-item-num">1.4.1.1 - </span>Analysis of parameter sweep: promotion probabilities level 1 -&gt;2</a></div><div class="lev3"><a href="#Parameter-sweep:-Promotion-probabilities-level-2--&gt;-3"><span class="toc-item-num">1.4.2 - </span>Parameter sweep: Promotion probabilities level 2 -&gt; 3</a></div><div class="lev4"><a href="#Analysis-of-parameter-sweep:-promotion-probabilities-level-2--&gt;-3"><span class="toc-item-num">1.4.2.1 - </span>Analysis of parameter sweep: promotion probabilities level 2 -&gt; 3</a></div><div class="lev2"><a href="#Initialization-Cells---do-not-change"><span class="toc-item-num">1.5 - </span>Initialization Cells - do not change</a></div>
#
#  TO DO:
#  1.  Correct Model 3 information.  Right now, the text is just a copy of Model 2.  I couldn't remember what we did   for Model 3.  (Krishna)
#  2.  Add probabilities.  (Krishna)
#  3.  I was unclear when I said I wanted counts.  I only need the total Faculty N (average, range) for each figure.  The y axis should still be proportions, i.e. 0.xx, 0.yz etc. (Krishna)
#  4.  Add decision rule we ended up with for faculty size used for Models 2 & 3.  (Krishna)
#  5.  When I ask Jupyter to make a .pdf copy, FILE>DOWNLOAD AS>PDF FILE VIA LATEX, the progam doesn't recognize any end-of-page information.  For instance, the text stops just before the first paragraph of Model 2, paragraph 1.  This is obviously not good.  (Krishna)
#  6.  Fix Figure 1.  It now has an error in it and doesn't show up.  I don't remember changing anything(?)  (Krishna)
#  7.  Check all the baseline rates in tables.  I think some of them are wrong.  (Barbara)
#  8.  Add an explanation of error distributions (shaded areas).
#  9.  Re: Models 2 and 3.  Add decision rule for increasing or decreasing faculty size to text.  There will be two explanations, one for the replication model, which I believe conserves faculty numbers overall, and one for models 2 and 3, which allows a range of size.  I vaguely recall but don't remember the specifics. ADD DECISION RULE TO TEXT.  (Krishna)
#  10.  Add horizontal lines to plots that show the goal for proportion women.  (Krishna)
#
#  QUESTIONS:
#  1.  Is there a simple way to change the color and size of text?
#  2.  The results suggest several patterns... [**HOW MANY**]  It seems as if it's only one, i.e. the effect of approaching 0 faculty in any level.  Number two might be effects of the overall promotion probabilities relative to the overall hiring probabilities over time(?)  Right now this doesn't provide those overall probabilities.
#  3.  From what I understand now, we can't really test a promotion probability sweep with the replication model because a. it specifies that hiring comes before promotions, thus promotion probabilities are what's left over rather than a sweep, and b. total faculty N is conserved.  Is that correct?  [WE TALKED ABOUT THIS BUT I COULDN'T WRITE IT, WHICH MEANS I MUST NOT HAVE UNDERSTOOD THE ANSWERS.]
#  6.  "This analysis provides a vanilla outlook on all 3 models with the data maintained intact." [Does this mean there are no changes in the original hiring and attrition rates for Model 1 and no changes in original hiring, promotion and attrition rates for Models 2 & 3? Is this correct?  In addition it means that the number of faculty is not conserved in any of the three models?
#  7.  I assume that once the tables get translated into LaTex, I'll be able to format them better (i.e. merging cells, etc.)  Is that right?
#  8.  How many times is the simulation being run?  Where can I change the number of years?  Where do I find that info?  I assume at the end somewhere?  [NEED TO SPECIFY LOCATION IN CODE BETTER]
#  9.  DONE.  Wouldn't it be more accurate to give the promotion rate for the level below, i.e. the promotion rate for female assistants = 0.0555, instead of the promotion rate for female associates = 0.0555?
#  10.  Which model, i.e. replication, promote-hire, hire-promote, do the sweeps use?

# %% [markdown]
# # 1.0  Management Department - Three Models
# ## Replication, Hire-Promote and Promote-Hire Simulations (4.2.16)
#
# ## 1.1   Data
#
# The data for these analyses come from the faculty personnel office of a university in the Western United States.  Eight years of faculty data were obtained, 2004-05 through 2012-13.  The data follow the hiring, promotion and attrition of each full-time ladder faculty member.  Hiring includes all faculty hired externally for assistant, associate and full professor positions.  Attrition includes all faculty who leave for any reason.  Promotions include faculty who move from assistant to associate professor and from associate to full professor.
#
# Table 1 shows the actual hiring, promotion and attrition rates calculated from the eight years of faculty data.
#
#                    ASSISTANT PROF (LEV 1)   ASSOCIATE PROF (LEV 2)	FULL PROF (LEV 3)
#
# | BASELINE RATES      | women   |  men        | women   |  men        | women  |  men
# | --------------      | -----   | ------      | -----   |------       | ------ |-------
# | hiring              | 0.1724  | 0.8276      | 0.0400  | 0.0600      | 0.1667 | 0.8333
# | promotion           | 0.0555  | 0.0611      | 0.1905  | 0.1149      | NA     | NA
# | attrition           | 0.0556  | 0.0687      | 0.0000  | 0.0574      | 0.0741 | 0.0399
#
#
#
# ## 1.2  Model Specifications
#
# There are three simulation models employed in this analysis.  All use the department's actual hiring, promotion and attrition rates.  They require that the number of faculty is an integer value rather than a fractional one.  Replacements in all models are selected using a cascade that begins with full professor.  The models differ in how they incorporate promotion rates.
#
# Decision rule for fractional faculty.  The department's hiring, attrition and promotion rates result in many fractional faculty at the end of each year.  For instance, if the hiring rate for female assistant professors is 0.25, then if there are five hires, 1.25 of them should be women.  However, because of the integer requirement, the model needs to decide whether to hire one or two women.  The decision rule is 1) round the fraction down to the nearest integer, 2) randomly select a number from a uniform distribution and 3) hire two women if the random numbers falls below the hiring rate for that year and hire one if the random number falls above. This decision rule is used every time a fractional faculty member results.  This means it is applied separately to women and to men at each career level and for each of the three rates (hiring, attrition and promotion).
#
# **Model 1:  Replication.** This model is a stochastic version of the original model.  It is a replication in that it uses the original model's hiring and atrition rates as well as its' assumptions about how replacements are filled.  Similar to the original model, actual promotion rates are not incorporated and change each year.  They are set using the percentage of female assistant and associate faculty the year before the promotion.  Different from the original model, the replication counts faculty using integers rather than fractions.  The decision rule for promotions maintains roughly the same number of faculty at each career level throughout the simulation.
#
# 1.  Full Professor replacements (Level 3).  After full professors leave, replacements are selected first by outside hires at the department's full professor hiring rates.  Remaining vacancies are filled by associate professor promotions.  The decision rule for fractional faculty is applied to all replacements.
#
# 2.  Associate Professor replacements (Level 2).  All associate professors who leave or are promoted are replaced first by outside hires at the department's associate professor hiring rates.  Remaining vacancies are filled by assistant professor promotions.  The decision rkule for fractional faculty is applied to all replacements.
#
# 3.  Assistant Professor replacements (Level 1).  All assistant professors who leave or are promoted are replaced by outside hires.
#
# [**KRISHNA:  WOULD YOU CORRECT MODEL 3?  RIGHT NOW, MODEL 3 IS A COPY OF MODEL 2.  I COULDN'T REMEMBER THE MODEL 3 DETAILS.**]
#
# **MODEL 2:  Hire-Promote.**  This is a stochastic model using actual hiring, attrition and promotion rates.  Similar to Model 1, replacements are selected using a cascade that beings with full professors, with replacements for women selected before replacements for men.  This model differs from Model 1 in several ways.  First, faculty are promoted using actual promotion rates, which means these rates are fixed rather than variable throughout the simulation.   Second, the number of faculty at each level is not conserved.  It may increase or decrease.  The decision rule for increasing or decreasing faculty size is: [XXXXXX WHAT DECISION RULE DID WE END UP USING?]
#
# 1.   Full Professor replacements (Level 3). Full professors leave at the department's full professor attrition rate. Next, full professors are hired using the full professor hiring rate. Finally, associate professors are promoted using the associate professor promotion rate.
#
# 2.  Assocate professor replacements (Level 2).  Associate professors leave at the department's associate professor attrition rate. Next, associate professors are hired using the associate professor hiring rate. Finally, assistant professors are promoted using the assistant professor promotion rate.
#
# 3. Assistant Professor replacements (Level l). Assistant professors leave at the department's assistant level attrition rate. Next, assistant professors are hired using the assistant professor hiring rate. Finally, assistant professors are promoted to associate using the assistant professor promotion rate.
#
#
# **MODEL 3:  Promote-Hire.**  REVISE EVERYTHING BELOW FOR PROMOTE-HIRE MODEL.  This is a stochastic model using actual hiring, attrition and promotion rates.  Similar to Model 1, replacements are selected using a cascade that beings with full professors, with replacements for women selected before replacements for men.  This model differs from Model 1 in several ways.  First, faculty are promoted using actual promotion rates, which means these rates are fixed rather than variable throughout the simulation.   Second, the number of faculty at each level is not conserved.  It may increase or decrease.  The decision rule for increasing or decreasing faculty size is: XXXX
#
# 1.   Full Professor replacements (Level 3). Full professors leave at the department's full professor attrition rate. Next, full professors are hired using the full professor hiring rate. Finally, associate professors are promoted using the associate professor promotion rate.
#
# 2.  Assocate professor replacements (Level 2).  Associate professors leave at the department's associate professor attrition rate. Next, associate professors are hired using the associate professor hiring rate. Finally, assistant professors are promoted using the assistant professor promotion rate.
#
# 3. Assistant Professor replacements (Levell). Assistant professors leave at the department's assistant level attrition rate. Next, assistant professors are hired using the assistant professor hiring rate. Finally, assistant professors are promoted to associate using the assistant professor promotion rate.
#
#
# ## 1.3  Baseline Results
# ## This section shows the results for the faculty overall by level and for the faculty by gender by level.
#
# **1.3.1 Change in Proportion of Female Faculty Over Time.** Figure 1 below shows change in the overall proportion of female faculty for each of the three models when the original hiring and attrition rates are used for Model 1 and the original hiring, attrition and promotion rates are used for Models 2 and 3.
#
# The results suggest several [**HOW MANY?**] patterns due to the flow of faculty though the three career levels. One results when the number of women or men in associate or full professor positions declines to 0. When this occurs all possible promotions are only possible for a single gender. This result serves to maintain the overall gender imbalance of the department.
#
# This analysis provides a vanilla outlook on all 3 models with the data maintained intact [**DOES THIS MEAN NO CHANGES IN HIRING, PROMOTION AND ATTRITION RATES? IT DOESN'T INCLUDE MAINTAINING THE NUMBER OF FACULTY, RIGHT?**). These analyses represent a baseline for subsequent analyses.

# %% [markdown]
# ### 1.3.1  Change in Proportion of Women Over Time
#
# Figure 1 shows the change in the proportion of women for 40 years using the three models:  replication, hire-promote and promote-hire.  The proportion increases 4-6% depending on the model.
#
# The replication model reproduces the values of the mathematical model to four decimal places (filename).  The promote-hire models outperform the hire-promote models because the probability of adding a female full is higher for promoting an associate (0.1905) than from hiring a full (0.0250).  Similarly, the probability of adding a female associate is higher for promoting an assistant (0.0555) than for hiring an associate  (.0400). All assistants are hired so there is no differential promotion effect.  This would be possible if a fourth level were added to include the availability of doctoral students.  These data are unavailable.
#
# The tables below show hiring, promotion and attrition rates for women and men at each level.
#
#                    ASSISTANT PROF (LEV 1)   ASSOCIATE PROF (LEV 2)	FULL PROF (LEV 3)
#
# | BASELINE RATES      | women   |  men        | women   |  men        | women  |  men
# | --------------      | -----   | ------      | -----   |------       | ------ |-------
# | hiring              | 0.1724  | 0.8276      | 0.0400  | 0.0600      | 0.1667 | 0.8333
# | promotion           | 0.0555  | 0.0611      | 0.1905  | 0.1149      | NA     | NA
# | attrition           | 0.0556  | 0.0687      | 0.0000  | 0.0574      | 0.0741 | 0.0399

# %%
e.plot_comparison_gender_proportion(100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-aa30b5980438> in <module>()
# ----> 1 e.plot_comparison_gender_proportion(100)
#
# NameError: name 'e' is not defined

# %% [markdown]
# ### 1.3.2  Change in Proportion of Women Over Time by Level (Proportions)
# [**This next set of analyses should show changes in proportions rather than changes in counts.  The average N and range for each level should go in a heading or footer.  The count similations can be used to provide an example of what happens to flows**]
#
# ### 1.3.3  Change in Proportion of Women Over Time by Level (Counts)
# In this section we display individual male/female counts for each department for each year. The results show a peculiar nonlinear trend below the surface of the overall gender proportion.
#
# ### 1.3.4  Probability of Acheiving Goal
# [NEED TO ADD A HORIZONTAL LINE FOR THE GOAL.]

# %% [markdown]
# ### DOES THE FIGURE TITLE GO HERE?

# %%
e.plot_comparison_detail(100)

# %% [markdown]
# ### 1.3.5  Discussion
#
#
# The behavior of the promote-hire and hire-promote models is very similar except for male associate professor. At level 1, both models have to hire men/women because there is no promotion into level 1.
#
# #### Replication(Promote-hire) model
#
# The promote-hire model shows a decline in the number of male assistant professors as they are promoted to associate professor. We don't see a lot of growth in level 1 for either men or women because in this model all vacancies arise at the top and trickle down. Hence there are likely only a few vacancies if any offered to level 1 candidatew, and even then there is almost a certainly of hiring men given a probability of 83%. Since there is very little likelihood for women to enter at this level, the number of level 1 women dwindles over time.
#
# The behavior at level 2 is especially interesting. Because the probability of promotion from level 1 to 2 is lower than the probability of promotion from level 2 to 3, any woman entering level 2 is likely to be promoted after a few years. However, as women are promoted into level 3, not enough women are promoted out of level 1 to take their place. Hence over time the number of level 2 women shrinks towards zero. When the number of females at level 2 hits zero, then women who leave level 3 due to attrition cannot be replaced by other women--since there are none. The dearth of women at level 2 leads to more men being promoted from 2 to 3--thus leading to a shrinkage of men at level 2.
#
# **One challenge with this model is that the promotion rate is variable, based upon the proportion of females at each level. As the number of females falls at level two, this makes the promotion rate of women at level 2 smaller and smaller. An appropriate alternative would be to us the same promotion rate for men/women as the hire-promote model.**
#
#
# #### Promote-hire model
#
# The Promote-hire fp model essentially follows the same pattern as the Replication model.
#
# #### Hire-promote model
#
# The hire-promote model seems to work well for men, especially at level 2. The chances of a man being hired are always better for hiring versus promotion--as per the tables above. Hence the hire first model allows more men to be hired, especially at level 2. Women have a better chance of being promoted to level 3 from level 2, so this allows some accumulation of men at level 2. Once the number of women at level 2 falls to zero, the accumulation of men flattens as only men can now be promoted from level 2 to 3.

# %% [markdown]
# ## 1.4  Parameter Sweeps -- Effect of Different Hiring Rates
#
# ### 1.4.1 Transition from Assistant to Associate Professor
# 1.4.2  Transition from Assistant to Associate Professor (Overall)
#
# 1.4.3  Transition from Assistant to Associate Professor (by Level)
#
#
# In this section we examine how variations in critical model parameters effect the final outcomes of each model. [WHICH MODEL DO THESE SWEEPS USE?]
#
# We will sweep a few test parameters.
#
# * promotion probability level 1 -> 2
# * promotion probability level 2 ->3
#
# We will address each sweep in turn.
#
# ## 1.5  Parameter Sweeps -- Effect of Different Promotion Rates
#
# In this section we examine how variations in critical model parameters affect the final outcomes of each model. [WHICH MODEL DO THESE SWEEPS USE?]
#
# ### 1.5.1  Effect of Promotion Rates on the Transition From Assistant to Associate Professors
#
# #### The first sweep varies the probability of promotion of women from Assistant to Associate professor.
#
# The chart below shows the targeted parameter. This chart may look confusing but the value 0.0555 represents the probability of promotion of a woman *into* level 2.
#
#
#
# Model: promote-hire / level 2
#
# | method        | men           | woman |
# | ------------- |:-------------:| -----:|
# | promote       |  0.0635        | **0.0555** |
# | hire          |  0.075     |  0.05|

# %%
number_of_runs = 100
upper_bound = 0.6
lower_bound = 0.05
number_of_sweep_increments = 40
e.plot_parameter_sweep_gender_proportion(number_of_runs,'female_promotion_probability_1', 
                                         lower_bound, upper_bound, 
                                         number_of_sweep_increments)

# %% [markdown]
# #### Analysis of parameter sweep: promotion probabilities level 1 ->2
#
#
# The change in the promotion probabilities from level 1 -> 2 seems to only affect the promote-hire fp model. This makes sense this this model promotes before hiring and hence makes the best use of the increased promotion rate. The other advantage of this increased promotion rate is that there is less chance of the depletion of women at level 2--thus forcing all promotions to level 3 to be men.
#
# In the plots below I explore this parameter sweeps for promotion in greater detail. The parameter sweep chart only shows the department gender proportion for the final year of each simulation. Below I generate the simulation results on a year-by-year basis to better understand how the parameter sweep final year results are computed.
# ##### Female promotion probability at 10 percent
#
# The increase in promotion probability by 5% over the estimated value does little change the overall gender balance in the department. However, the gender proportion chart below does show that as we alter the promotion probability for women, the purple shaded region begins to have greater density in a range of gender proportions that would mean substantial improvement.

# %%
data_mgmt['female_promotion_probability_1'] = 0.1
e.plot_comparison_gender_proportion(100)

# %%
data_mgmt['female_promotion_probability_1'] = 0.1
e.plot_comparison_detail(100)

# %% [markdown]
# ##### Female promotion probability at 40 percent
#
# As the female promotion probability rises to 40%, the overall gender balance of the department remains pretty much constant. So even at a 40% promotion rate, no significant improvement in overall equity occurs. The one thing to note is that as the level 1 promotion rate increases, we see more women at level 2 in the detail chart below. It seems to take a longer time for the level 2 curves to reach zero.

# %%
data_mgmt['female_promotion_probability_1'] = 0.4
e.plot_comparison_gender_proportion(100)

# %%
data_mgmt['female_promotion_probability_1'] = 0.4
e.plot_comparison_detail(100)

# %% [markdown]
# ##### Female promotion probability at 70 percent
#
# Again, as the female promotion probability at level 1 rises to 70% we still do not see much improvement in overall gender balance over time.

# %%
data_mgmt['female_promotion_probability_1'] = 0.7
e.plot_comparison_gender_proportion(100)

# %%
data_mgmt['female_promotion_probability_1'] = 0.7
e.plot_comparison_detail(100)

# %% [markdown]
# ### Parameter sweep: Promotion probabilities level 2 -> 3
#
# The chart below shows the targeted parameter. This chart may look confusing but the value 0.1905 represents the probability of promotion of a woman *into* level 3.
#
# Model: promote-hire / level 3
#
# | method        | men           | woman  |
# | ------------- |:-------------:| -----:|
# | promote       | 0.1149         |** 0.1905**  |
# | hire          | 0.125         |  0.025  |

# %%
number_of_runs = 100
upper_bound = 0.8
lower_bound = 0.1
number_of_sweep_increments = 15
e.plot_parameter_sweep_gender_proportion(number_of_runs,'female_promotion_probability_2', 
                                         lower_bound, upper_bound, 
                                         number_of_sweep_increments)

# %% [markdown]
# #### Analysis of parameter sweep: promotion probabilities level 2 -> 3
#
# The one trend that seems interesting in this parameter sweep is the deterioration in gender equity as the promotion probability of women increases for the promote-hire fp model. There is also a corresponding small improvement in gender equity in the hire promote model. Detail analysis should hopefully shed some light on this behavior.
#
# **Based upon the detailed analysis below, the trends of increase or decrease in gender equity over time don't seem to be genuine. ** Instead these improvement might simply be the result of random variation instead of structural change. The curves below show that indeed as the promotion rate for women increases, more women move from level 1 to level 2--hence the number of women at level 2 quickly collapses to zero. The fact that the number of women at level 3 continues to grow even as the number of women at level 2 seems to collapse suggests that there are women entering level 2 from level 1, but they are quickly being promoted to level 3.
#
# And interesting trend is also that the number of women at leve1 1 seems to remain a bit more constant compared to the promotion of women from level 1 to 2. This change seems the result of vacancies that are created as women are promoted from level 2 to level 3. As these vacancies arise, there is a chance for those vacancies to be filled by promotion of women from level 1 to 2. When level 1 women are promoted, this creates corresponding vacancies at level 1 and hence opportunities to hire women.
#
# ##### Female promotion probability at 10 percent
#
# The 10 percent threshold is really not too useful since the empirical promotion rate is about 19%. But these plots of the 10 percent promotion rate set a baseline for comparison.

# %%
data_mgmt['female_promotion_probability_2'] = 0.1
e.plot_comparison_gender_proportion(100)

# %%
data_mgmt['female_promotion_probability_2'] = 0.1
e.plot_comparison_detail(100)

# %% [markdown]
# ##### Female promotion probability at 40 percent

# %%
data_mgmt['female_promotion_probability_2'] = 0.4
e.plot_comparison_gender_proportion(100)

# %%
data_mgmt['female_promotion_probability_2'] = 0.4
e.plot_comparison_detail(100)

# %% [markdown]
# ##### Female promotion probability at 70 percent

# %%
data_mgmt['female_promotion_probability_2'] = 0.7
e.plot_comparison_gender_proportion(100)

# %%
data_mgmt['female_promotion_probability_2'] = 0.7
e.plot_comparison_detail(100)

# %% [markdown]
# ## Initialization Cells - do not change

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (13, 13)
matplotlib.rcParams.update({'font.size': 14})
import matplotlib.pyplot as plt
import builtins
import os, sys
from IPython.lib import deepreload
builtins.reload = deepreload.reload
# %run models/Models.py
# %run models/Basic_stochastic_model.py
# %run models/Replication_model.py
# %run models/Stochastic_model_with_promotion.py
# %run models/Stochastic_model_with_promotion_and_first_hiring.py
# %run models/Basic_stochastic_model_fixed_promotion.py
# %run comparisons/Comparison.py
# %load_ext autoreload
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from IPython.core.display import HTML

def css_styling():
    styles = open("styles/custom_lb.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <link href='https://fonts.googleapis.com/css?family=Montserrat' rel='stylesheet' type='text/css'>
# <link href='https://fonts.googleapis.com/css?family=Lato' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Fenix' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Source+Code+Pro:300,400' rel='stylesheet' type='text/css'>
# <style>
#     @font-face {
#         font-family: 'Montserrat', sans-serif;
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width:800px;
#         margin-left:16% !important;
#         margin-right:auto;
#     }
#     h1 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     h2 {
# ...

# %%
number_of_females_1 = 3
number_of_females_2 = 3
number_of_females_3 = 2
number_of_males_1 = 11
number_of_males_2 = 12
number_of_males_3 = 43
number_of_initial_vacancies_1 = 5.303 
number_of_initial_vacancies_2 = 5.9
number_of_initial_vacancies_3 = 8.31
hiring_rate_women_1 = 0.172
hiring_rate_women_2 = 0.4
hiring_rate_women_3 = 0.167
attrition_rate_women_1 = 0.056
attrition_rate_women_2 = 0.00
attrition_rate_women_3 = 0.074
attrition_rate_men_1 = 0.069
attrition_rate_men_2 = 0.057
attrition_rate_men_3 = 0.040
probablity_of_outside_hire_1 = 1
probability_of_outside_hire_2 = 0.125
probability_of_outside_hire_3 = 0.150
female_promotion_probability_1 = 0.0555
female_promotion_probability_2 = 0.1905
male_promotion_probability_1 = 0.0635
male_promotion_probability_2 = 0.1149
duration = 40

data_mgmt = {'number_of_females_1': number_of_females_1,
              'number_of_females_2': number_of_females_2,
              'number_of_females_3': number_of_females_3,
              'number_of_males_1': number_of_males_1,
              'number_of_males_2': number_of_males_2,
              'number_of_males_3': number_of_males_3,
              'number_of_initial_vacancies_1': number_of_initial_vacancies_1, 
              'number_of_initial_vacancies_2': number_of_initial_vacancies_2,
              'number_of_initial_vacancies_3': number_of_initial_vacancies_3,
              'hiring_rate_women_1':hiring_rate_women_1,
              'hiring_rate_women_2':hiring_rate_women_2,
              'hiring_rate_women_3':hiring_rate_women_3,
              'attrition_rate_women_1':attrition_rate_women_1,
              'attrition_rate_women_2':attrition_rate_women_2,
              'attrition_rate_women_3':attrition_rate_women_3,
              'attrition_rate_men_1':attrition_rate_men_1,
              'attrition_rate_men_2':attrition_rate_men_2,
              'attrition_rate_men_3':attrition_rate_men_3,
              'probablity_of_outside_hire_1':probablity_of_outside_hire_1,
              'probability_of_outside_hire_2': probability_of_outside_hire_2,
              'probability_of_outside_hire_3':probability_of_outside_hire_3,
              'female_promotion_probability_1': female_promotion_probability_1,
              'female_promotion_probability_2': female_promotion_probability_2,
              'male_promotion_probability_1' : male_promotion_probability_1,
              'male_promotion_probability_2' : male_promotion_probability_2,
              'duration':duration}

# %%
modlist = list([Replication_model(**data_mgmt), 
                Basic_stochastic_model(**data_mgmt), 
                Stochastic_model_with_promotion_and_first_hiring(**data_mgmt)])

modlist2 = list([Replication_model(**data_mgmt), 
                Basic_stochastic_model_fixed_promotion(**data_mgmt), 
                Stochastic_model_with_promotion_and_first_hiring(**data_mgmt)])

modlist_all = list([ 
                Basic_stochastic_model(**data_mgmt),
                Basic_stochastic_model_fixed_promotion(**data_mgmt), 
                Stochastic_model_with_promotion_and_first_hiring(**data_mgmt)])

c = Comparison(modlist)
d = Comparison(modlist2)
e = Comparison(modlist_all)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-5a1e72dd0dd1> in <module>()
# ----> 1 modlist = list([Replication_model(**data_mgmt),
#       2                 Basic_stochastic_model(**data_mgmt),
#       3                 Stochastic_model_with_promotion_and_first_hiring(**data_mgmt)])
#       4
#       5 modlist2 = list([Replication_model(**data_mgmt),
#
# /media/krishnab/jaimini/work/proj_gender_univ/src/python_proj/python_model/models/Replication_model.py in __init__(self, **kwds)
#      11
#      12     def __init__(self, **kwds):
# ---> 13         Base_model.__init__(self, **kwds)
#      14         self.name = "Replication Model(mathmod_orig)"
#      15         self.label = "Replication m"
#
# TypeError: __init__() missing 2 required positional arguments: 'max_threshold' and 'prob_random_growth'
