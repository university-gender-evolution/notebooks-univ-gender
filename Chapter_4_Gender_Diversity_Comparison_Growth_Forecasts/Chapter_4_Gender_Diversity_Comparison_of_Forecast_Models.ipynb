# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"><li><span><a href="#Comparison-of-Model-3-Forecast-Models" data-toc-modified-id="Comparison-of-Model-3-Forecast-Models-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Comparison of Model 3 Forecast Models</a></span><ul class="toc-item"><li><span><a href="#Comparison-of-Model-3-Forecast-Models:-Change-in-Proportion-of-Women" data-toc-modified-id="Comparison-of-Model-3-Forecast-Models:-Change-in-Proportion-of-Women-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Comparison of Model 3 Forecast Models: Change in Proportion of Women</a></span></li><li><span><a href="#Comparison-of-Model-3-Forecast-Models:-Probability-of-Achieving-25%-Women" data-toc-modified-id="Comparison-of-Model-3-Forecast-Models:-Probability-of-Achieving-25%-Women-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Comparison of Model 3 Forecast Models: Probability of Achieving 25% Women</a></span></li><li><span><a href="#Comparison-of-Model-3-Forecast-Models:-Change-in-Number-Women" data-toc-modified-id="Comparison-of-Model-3-Forecast-Models:-Change-in-Number-Women-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Comparison of Model 3 Forecast Models: Change in Number Women</a></span></li><li><span><a href="#Comparison-of-Model-3-Forecast-Models:-Department-Size" data-toc-modified-id="Comparison-of-Model-3-Forecast-Models:-Department-Size-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Comparison of Model 3 Forecast Models: Department Size</a></span></li></ul></li><li><span><a href="#Simulation-Options-and-Functions" data-toc-modified-id="Simulation-Options-and-Functions-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Simulation Options and Functions</a></span><ul class="toc-item"><li><span><a href="#Instructions-for-Plotting-Functions" data-toc-modified-id="Instructions-for-Plotting-Functions-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Instructions for Plotting Functions</a></span></li><li><span><a href="#Generate-CSV-File" data-toc-modified-id="Generate-CSV-File-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Generate CSV File</a></span><ul class="toc-item"><li><span><a href="#Export-Model-3-linear-growth-1.5-percent" data-toc-modified-id="Export-Model-3-linear-growth-1.5-percent-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Export Model 3 linear growth 1.5 percent</a></span></li><li><span><a href="#Export-Model-3-4-year-forecasts" data-toc-modified-id="Export-Model-3-4-year-forecasts-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Export Model 3-4 year forecasts</a></span></li><li><span><a href="#Export-Model-3-Forecast---3-year-moving-average" data-toc-modified-id="Export-Model-3-Forecast---3-year-moving-average-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Export Model 3 Forecast - 3 year moving average</a></span></li><li><span><a href="#Export-Model-3-Forecast---4-year-moving-average" data-toc-modified-id="Export-Model-3-Forecast---4-year-moving-average-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>Export Model 3 Forecast - 4 year moving average</a></span></li></ul></li><li><span><a href="#Export-Notebook-to-Pdf-(Not-yet-working)" data-toc-modified-id="Export-Notebook-to-Pdf-(Not-yet-working)-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Export Notebook to Pdf (Not yet working)</a></span></li></ul></li></ul></div>

# %%
import builtins
import os, sys
import time
import pyugend
import datetime
from IPython.lib import deepreload
builtins.reload = deepreload.reload
from ipywidgets import widgets
from IPython.display import display
from bokeh.io import show, output_notebook
from bokeh.layouts import gridplot
from bokeh.palettes import Viridis3
from bokeh.plotting import figure
#from bokeh.charts import defaults
from bokeh.resources import INLINE
from IPython.display import display
width = 700
height = 700

import warnings
warnings.filterwarnings('ignore')

output_notebook(resources=INLINE)
# %reload_ext autoreload
time.sleep(1)

pdf = True

from IPython.display import Image
if pdf:
    from bokeh.io import export_png
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="cc07665b-d33f-4c47-a2f5-a7ee540d29af">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Comparison of Model 3 Forecast Models

# %% [markdown]
# ##  Comparison of Model 3 Forecast Models: Change in Proportion of Women

# %%
#<overall:gender_proportion>


plot_settings = {'plottype': 'gender proportion',
                 'intervals': 'empirical',
                 'number_of_runs': 100,
                 'target': 0.25,
                 'xlabel': 'Years',
                 'ylabel': 'Proportion Women',
                 'title': ' Comparison of 3 Forecast models, Model 3',
                 'model_legend_label': ['Model 3-Linear Growth (1.5%)',
                                        'Model 3-4 Year Forecast(1%/year)',
                                        'Model 3-3 Year Moving Avg',
                                        'Model 3-4 Year Moving Avg'],
                 'target_plot':  True,
                 'target_plot_legend_label':  'Target Proportion', 
                 'legend_location': 'top_right',
                 'height_': 700,
                 'width_': 700,

                 }



if pdf:
    export_png(u.plot_comparison_overall_chart(**plot_settings), filename='img/gend_proportion_overall.png')
    display(Image('img/gend_proportion_overall.png'))
else:
    show(u.plot_comparison_overall_chart(**plot_settings))

# %% [markdown]
# ##  Comparison of Model 3 Forecast Models: Probability of Achieving 25% Women

# %%
#Probability of Achieving 25% Women, Model 3 (Promote-Hire)
#<overall:probability_proportion>

plot_settings = {'plottype': 'probability proportion',
                 'intervals': 'empirical',
                 'number_of_runs': 200,
                 'target': 0.25,
                 'xlabel': 'Years',
                 'ylabel': 'Probability of Achieving Target',
                 'title': 'Comparison of Model 3 Forecast Models: Probability of Achieving 25% Women',
                 'model_legend_label': ['Model 3-Linear Growth (1.5%)',
                                        'Model 3-4 Year Forecast(1%/year)',
                                        'Model 3-3 Year Moving Avg',
                                        'Model 3-4 Year Moving Avg'],
                 'percent_legend_label': 'Reference Probability',
                 'legend_location': 'top_right',
                 'height_': 700,
                 'width_': 700,
                 'percent_line_plot': True
                 }

if pdf:
    export_png(u.plot_comparison_overall_chart(**plot_settings), filename='img/probability_proportion_overall.png')
    display(Image('img/probability_proportion_overall.png'))
else:
    show(u.plot_comparison_overall_chart(**plot_settings))

# %% [markdown]
# ##  Comparison of Model 3 Forecast Models: Change in Number Women

# %%
#<overall:gender_number>


plot_settings = {'plottype': 'gender numbers',
                 'intervals': 'empirical',
                 'number_of_runs': 100,
                 'target': 0.25,
                 'xlabel': 'Years',
                 'ylabel': 'Number of Women',
                 'title': ' Comparison of Model 3 Forecast Models: Change in Number Women ',
                 'model_legend_label': ['Model 3-Linear Growth (1.5%)',
                                        'Model 3-4 Year Forecast(1%/year)',
                                        'Model 3-3 Year Moving Avg',
                                        'Model 3-4 Year Moving Avg'],
                 'target_plot':  False,
                 'target_plot_legend_label':  'Target Proportion', 
                 'legend_location': 'top_right',
                 'height_': 700,
                 'width_': 700
                 }

if pdf:
    export_png(u.plot_comparison_overall_chart(**plot_settings), filename='img/gender_numbers_overall.png')
    display(Image('img/gender_numbers_overall.png'))
else:
    show(u.plot_comparison_overall_chart(**plot_settings))

# %% [markdown]
# ## Comparison of Model 3 Forecast Models: Department Size

# %%
plot_settings = {'plottype': 'department size',
                     'intervals': 'empirical',
                     'number_of_runs': 100,
                     # number simulations to average over
                     'target': 0.25,
                     # target percentage of women in the department
                     # Main plot settings
                     'xlabel': 'Years',
                     'ylabel': 'Department Size',
                     'title': 'Comparison of Model 3 Forecast Models: Department Size',
                     'line_width': 2,
                     'transparency': 0.25,
                     'model_legend_label': ['Model 3-Linear Growth (1.5%)',
                                        'Model 3-4 Year Forecast(1%/year)',
                                        'Model 3-3 Year Moving Avg',
                                        'Model 3-4 Year Moving Avg'],
                     'legend_location': 'top_right',
                     'height_': height,
                     'width_': width,
                     'year_offset': 0

                     }
if pdf:
    export_png(u.plot_comparison_overall_chart(**plot_settings), filename='img/dept_size_overall.png')
    display(Image('img/dept_size_overall.png'))
else:
    show(u.plot_comparison_overall_chart(**plot_settings))

# %% [markdown]
# # Simulation Options and Functions

# %%
from IPython.core.display import HTML

def css_styling():
    styles = open("../styles/custom_lb.css", "r").read()
    return HTML(styles)
css_styling()

from IPython.core.display import display, HTML

# %%
number_of_females_1 = 3
number_of_females_2 = 3
number_of_females_3 = 2
number_of_males_1 = 11
number_of_males_2 = 12
number_of_males_3 = 43
number_of_initial_vacancies_1 = 5.303 
number_of_initial_vacancies_2 = 5.9
number_of_initial_vacancies_3 = 8.31
hiring_rate_women_1 = 0.172
hiring_rate_women_2 = 0.4
hiring_rate_women_3 = 0.167
attrition_rate_women_1 = 0.056
attrition_rate_women_2 = 0.00
attrition_rate_women_3 = 0.074
attrition_rate_men_1 = 0.069
attrition_rate_men_2 = 0.057
attrition_rate_men_3 = 0.040
probability_of_outside_hire_1 = 1
probability_of_outside_hire_2 = 0.125
probability_of_outside_hire_3 = 0.150
female_promotion_probability_1 = 0.0555
female_promotion_probability_2 = 0.1905
male_promotion_probability_1 = 0.0635
male_promotion_probability_2 = 0.1149
duration = 12
upperbound = 84
lowerbound = 64
variation_range = 3


data_mgmt = { 'number_of_females_1': number_of_females_1,
              'number_of_females_2': number_of_females_2,
              'number_of_females_3': number_of_females_3,
              'number_of_males_1': number_of_males_1,
              'number_of_males_2': number_of_males_2,
              'number_of_males_3': number_of_males_3,
              'number_of_initial_vacancies_1': number_of_initial_vacancies_1, 
              'number_of_initial_vacancies_2': number_of_initial_vacancies_2,
              'number_of_initial_vacancies_3': number_of_initial_vacancies_3,
              'hiring_rate_women_1':hiring_rate_women_1,
              'hiring_rate_women_2':hiring_rate_women_2,
              'hiring_rate_women_3':hiring_rate_women_3,
              'attrition_rate_women_1':attrition_rate_women_1,
              'attrition_rate_women_2':attrition_rate_women_2,
              'attrition_rate_women_3':attrition_rate_women_3,
              'attrition_rate_men_1':attrition_rate_men_1,
              'attrition_rate_men_2':attrition_rate_men_2,
              'attrition_rate_men_3':attrition_rate_men_3,
              'probability_of_outside_hire_1':probability_of_outside_hire_1,
              'probability_of_outside_hire_2': probability_of_outside_hire_2,
              'probability_of_outside_hire_3':probability_of_outside_hire_3,
              'female_promotion_probability_1': female_promotion_probability_1,
              'female_promotion_probability_2': female_promotion_probability_2,
              'male_promotion_probability_1' : male_promotion_probability_1,
              'male_promotion_probability_2' : male_promotion_probability_2,
              'duration':duration,
              'upperbound': upperbound,
              'lowerbound': lowerbound,
              'variation_range': variation_range}

# %%
modlist = list([pyugend.ModelGenderDiversityLinearGrowth(**data_mgmt),
                pyugend.ModelGenderDiversityGrowthForecastIncremental(**data_mgmt),
                pyugend.ModelGenderDiversityGrowthForecastIncremental(**data_mgmt)])

modlist[0].init_default_hiring_rate()
modlist[1].init_default_hiring_rate()
modlist[2].init_default_hiring_rate()
modlist[0].init_growth_rate(0.0201)
modlist[1].init_growth_rate([0.034, -0.008, 0.025])
modlist[2].init_growth_rate(pyugend.DataManagement.DataManagement().get_field('mvg_avg3_deptsize'))

t = pyugend.Comparison([modlist[0]])
s = pyugend.Comparison([modlist[1]])
r = pyugend.Comparison([modlist[2]])
u = pyugend.Comparison(modlist)

# %%
customize = False

if customize:
    # fill in custom values
    hiring_rate_f1 = 0
    hiring_rate_f2 = 0
    hiring_rate_f3 = 0
    hiring_rate_m1 = 0
    hiring_rate_m2 = 0
    hiring_rate_m3 = 0

    r.mlist[0].init_hiring_rates(hiring_rate_f1,
                                hiring_rate_f2,
                                hiring_rate_f3,
                                hiring_rate_m1,
                                hiring_rate_m2,
                                hiring_rate_m3)
  
    modlist[2].init_hiring_rates(hiring_rate_f1,
                                hiring_rate_f2,
                                hiring_rate_f3,
                                hiring_rate_m1,
                                hiring_rate_m2,
                                hiring_rate_m3)

# %% [markdown]
# ## Instructions for Plotting Functions

# %% [markdown]
# This section lays out instructions for customizing the charts displayed throughout this notebook. The different types of charts are denoted by special tags at the top of the plot cell. The four plot types are denoted as:
#
#  - `#<overall>`:  An overall chart displays the result of a department-wide summary statistic for a single model.
#  - `#<bylevel>`:  A bylevel chart displays the results of a single summary statistic for a each professor-level of a single model.
#  - `#<comparison-overall>`:  A comparison-overall chart compares two or more models on one department-wide statistic.
#  - `#<comparison-bylevel>`:  A comparison-bylevel compares two or more models one a single professor-level statistic.
#
# The chart tag is also augmented with an indication of which statistic is displayed in the chart. The common summary statistics are:
#
#  - gender_proportion: the percentage of women in the department or by level.
#  - probability_proportion: the probability that the department may achieve a target gender proportion in a given year
#  - unfilled_vacancies: The number of unfilled vacancies remaining at the end of year, after all hiring and promotion activity is complete.
#  - department_size: The total size of the department for a given year.
#  - male_female_numbers: The number of males and females in a department for a given year.

# %% [markdown]
#      plot_settings = {'plottype': 'gender proportion',
#                  'number_of_runs': 100, # number simulations to average over
#                  'target': 0.25, # target percentage of women in the department
#                  'caption': 'The red line shows a target of .25 women',
#
#                  # Main plot settings
#                  'xlabel':'Years',
#                  'ylabel': 'Proportion of Women Overall',
#                  'title': 'Figure 4.1.1a:  Model 1 - Change in *Proportion* Women Overall',
#                  'line_width': 2,
#                  'xmin': 0,
#                  'ymin': 0,
#                  #'xmax': 40,
#                  #'ymax': 1.0,
#                  'transparency': 0.25,
#                  'marker_shape': None,
#                  'linecolor': 'green',
#                  'model_legend_label': 'Simulated Probability',
#                  'legend_location': 'upper right',
#
#                  #Optional Parameters
#                  #Target value plot settings
#                  'target_plot': True,
#                  'color_target': 'red',
#                  'color_percent_line': 'red',
#                  'target_plot_line_style': '--',
#                  'target_plot_linewidth': 2,
#                  'target_plot_legend_label': 'Target',
#
#                  #Percent plot settings
#                  'percent_line_plot': False,
#                  'percent_line_value': 0.5,
#                  'percent_line_style': '-.',
#                  'percent_linewidth': 2,
#                  'percent_legend_label': 'Reference Line',
#
#                  #Male Female numbers plot settings
#                  'male_female_numbers_plot': False,
#                  'mf_male_color' : 'black',
#                  'mf_target_color' : 'red',
#                  'mf_male_label' : 'Male',
#                  'mf_target_label': 'Target',
#                  'mf_male_linestyle' : '-',
#                  'mf_target_linestyle': '-',
#                  'mf_male_linewidth' :2,
#                  'mf_target_linewidth' : 2
#                  }

# %% [markdown]
# ## Generate CSV File
#
# The cell below will generate a `csv` file with a requested number of model runs. To generate the csv, the user must specify three pieces of information, and then run the cell.
#
#   - **Model Choice**: The title of the model used to identify this model in the CSV file
#   - **Model Label**:  The name of the model used to name the CSV file.
#   - **Number of Runs**: The number of times the model is executed for export
#
# To generate the export files, choose the cell below with the appropriate model. Then update the Model Choice, Model Label, and Number of runs variables. finally execute the cell. The new CSV files will be located in the same directory as the notebook.

# %% [markdown]
# ### Export Model 3 linear growth 1.5 percent

# %%
# Please specify the following variables for the export file.
model_choice = 'Model 3 linear growth 1.5 percent'
model_label = 'Model 3 linear growth 1.5 percent'
number_of_runs = 100

t.export_model_run(model_label, model_choice, number_of_runs)

# %% [markdown]
# ### Export Model 3-4 year forecasts

# %%
# Please specify the following variables for the export file.
model_choice = 'Model 3 - 4 year forecasts'
model_label = 'Model 3 - 4 year forecasts'
number_of_runs = 100

s.export_model_run(model_label, model_choice, number_of_runs)

# %% [markdown]
# ### Export Model 3 Forecast - 3 year moving average

# %%
# Please specify the following variables for the export file.
model_choice = 'Model 3 Forecast Growth - 3 year moving average'
model_label = 'Model 3 Forecast Growth - 3 year moving average'
number_of_runs = 100

r.export_model_run(model_label, model_choice, number_of_runs)

# %% [markdown]
# ### Export Model 3 Forecast - 4 year moving average

# %%
# Please specify the following variables for the export file.
model_choice = 'Model 3 Forecast Growth - 4 year moving average'
model_label = 'Model 3 Forecast Growth - 4 year moving average'
number_of_runs = 100

q.export_model_run(model_label, model_choice, number_of_runs)

# %% [markdown]
# ## Export Notebook to Pdf (Not yet working)

# %% [markdown]
# Run the cell below to generate a pdf version of this notebook. Once the pdf is generated, you will find it listed among the files in the jupyter file listing tab.

# %%
! /u/local/Modules/3.2.6/bin/modulecmd load texlive

# %%
i = datetime.datetime.now()

fname= 'notebook_export_'+ str(i.isoformat())


##!jupyter nbconvert --to pdf mgmt_notebook05092016.ipynb --output $fname
# !jupyter nbconvert --to pdf Chapter_4_Gender_Diversity_Comparison_of_Forecast_Models.ipynb --output $fname
# Out:
# [NbConvertApp] Converting notebook Chapter_4_Gender_Diversity_Comparison_of_Forecast_Models.ipynb to pdf
# /media/krishnab/lakshmi/anaconda3/envs/pGendUniv/lib/python3.6/site-packages/nbconvert/filters/datatypefilter.py:41: UserWarning: Your element with mimetype(s) dict_keys(['text/html']) is not able to be represented.
#   mimetypes=output.keys())
# /media/krishnab/lakshmi/anaconda3/envs/pGendUniv/lib/python3.6/site-packages/nbconvert/filters/datatypefilter.py:41: UserWarning: Your element with mimetype(s) dict_keys(['application/javascript', 'application/vnd.bokehjs_load.v0+json']) is not able to be represented.
#   mimetypes=output.keys())
# [NbConvertApp] Support files will be in notebook_export_2018-01-22T11:13:02.753568_files/
# [NbConvertApp] Making directory notebook_export_2018-01-22T11:13:02.753568_files
# [NbConvertApp] Making directory notebook_export_2018-01-22T11:13:02.753568_files
# [NbConvertApp] Making directory notebook_export_2018-01-22T11:13:02.753568_files
# ...
